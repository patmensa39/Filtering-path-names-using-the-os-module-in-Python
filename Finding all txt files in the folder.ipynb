# %%
import os 
import glob

# %%
def set_working_directory(folder_path):
    os.chdir(folder_path)
    new_directory = os.getcwd()
    print("Patrick's Current working directory is set to:", new_directory)

# Set the working directory back to the folder you want to work with.
folder_path = r"C:\Users\patme\OneDrive\Desktop\Data_Science\R_programming\data"
set_working_directory(folder_path)
# Out:
# Patrick's Current working directory is set to: C:\Users\patme\OneDrive\Desktop\Data_Science\R_programming\data

# %%
# Finding all recurvise files in the working directory
def all_txt_files():
    for item in glob.iglob('**/*txt*',recursive = True):
        print(item)
if __name__ == "__main__":
    all_txt_files()
# Out:
# a.txt
# airplanes.txt
# Ancovacontrasts.txt
# anova.data.txt
# aplam.txt
# asymptotic.txt
# b.txt
# B1.txt
# B2.txt
# B3.txt
# B4.txt
# b5 and big5 Code Book.txt
# B5.txt
# B6.txt
# B7.txt
# B8.txt
# berks.txt
# bioassay.txt
# bloodcells.txt
# blowfly.txt
# box.txt
# boxy.txt
# bubble.txt
# c.txt
# cancer.txt
# car.test.frame.txt
# cases.txt
# cells.txt
# chicagoemployees.txt
# chicks.txt
# chris.txt
# clusters.txt
# colony.txt
# competition.txt
# compexpt.txt
# contrasts.txt
# crossover.txt
# cull.txt
# curvedata.txt
# cv.map.txt
# daphnia.txt
# das.txt
# dates.txt
# Decay.txt
# density.txt
# diminish.txt
# directed.txt
# distribution.txt
# dombryo.txt
# dups.txt
# Environmental_Data_Deep_Moor_2012.txt
# Environmental_Data_Deep_Moor_2013.txt
# Environmental_Data_Deep_Moor_2014.txt
# Environmental_Data_Deep_Moor_2015.txt
# epilobium.txt
# error.bars.txt
# ethanol.txt
# expt1.txt
# f.test.data.txt
# factorial.txt
# factories.txt
# farms.txt
# fertilizer.txt
# fh.txt
# fisher.txt
# fishery.txt
# fishes.txt
# fishing.txt
# flies.txt
# flo.txt
# flowering.txt
# fltimes.txt
# fol.txt
# freqs.txt
# functionalresponse.txt
# fung.txt
# Fungi.txt
# Gain.txt
# gales.txt
# gammaplot.txt
# garden.ozone.txt
# gardens.txt
# germination.txt
# gpa.txt
# grasshopper.txt
# growth.txt
# herbicides.txt
# hier.txt
# hist.txt
# houses.txt
# hre.txt
# hump.txt
# hypermasc.txt
# idealfreeducks.txt
# incidence.txt
# induced.txt
# infection.txt
# inpatient.txt
# insects.txt
# interaction.txt
# ipomopsis.txt
# iris.txt
# iris22_file.txt
# irrigation.txt
# island.txt
# isolation.txt
# jantemp.txt
# jaws.txt
# kelly.txt
# kmeansdata.txt
# kmnos.txt
# kmx.txt
# kmy.txt
# lackoffit.txt
# lambdas.txt
# Levels.txt
# lex.txt
# lifeforms.txt
# light.txt
# lizards.txt
# lmedata1.txt
# lmedata2.txt
# lmedata3.txt
# lodata.txt
# logistic.txt
# logplots.txt
# longdata.txt
# Lynx.txt
# manova.txt
# manova2.txt
# map.places.txt
# mm.txt
# mode.txt
# monocultures.txt
# multivariate.txt
# murders.txt
# Muscle.txt
# myco.txt
# mytest.txt
# naydf.txt
# naydf2.txt
# nays.txt
# nbnumbers.txt
# nl.txt
# nlme.txt
# nonlinear.txt
# nvc.txt
# occupation.txt
# om.txt
# oneway.txt
# Ovary.txt
# owlrings.txt
# oxford weather.txt
# oy.txt
# ozone.data.txt
# pair.txt
# paired.txt
# panels.txt
# Parasite.txt
# parasites.txt
# pgfull.txt
# pgnine.txt
# pgr.txt
# pgstability.txt
# pgvar.txt
# phosphorus.txt
# photoperiod.txt
# pieces.txt
# piedata.txt
# pig.txt
# plotdata.txt
# plotfit.txt
# plots.txt
# pointsdata.txt
# Pollute.txt
# poly.txt
# power.txt
# power.x.txt
# power.y.txt
# Practice.txt
# productivity.txt
# pseudo_facebook.txt
# rabbitfences.txt
# ragwort.txt
# ragwortmap2006.txt
# random_network.txt
# rats.txt
# reaction.txt
# refuge.txt
# regdat.txt
# regression.txt
# repeated.txt
# repmeasures.txt
# report.txt
# results.txt
# roaches.txt
# robreg.txt
# rt.txt
# rt2.txt
# sales.txt
# sapdecay.txt
# sasilwood.txt
# scatter1.txt
# scatter2.txt
# seedlings.txt
# seedoutput.txt
# seeds.txt
# seedwts.txt
# sexratio.txt
# sexratio2.txt
# silwoodrank.txt
# silwoodspecies.txt
# SilwoodWeather.txt
# sizes.txt
# skeletons.txt
# skewdata.txt
# sleep.txt
# slugsurvey.txt
# smoothing.txt
# soaysheep.txt
# soaytest.txt
# soil.txt
# sortdata.txt
# sp1.txt
# sp2.txt
# spatialdata.txt
# species.txt
# Speciesarea.txt
# spending.txt
# splitcounts.txt
# splitplot.txt
# splityield.txt
# sslogistic.txt
# stat051.txt
# StateData Code Book.txt
# stream.txt
# streams.txt
# sulphur.dioxide.txt
# sward.txt
# sweepdata.txt
# Swiss_data.txt
# t.test.data.txt
# table.txt
# tabledata.txt
# tannin.txt
# taxa.txt
# taxon.txt
# taxonomy.txt
# tdata.txt
# temp.txt
# test.txt
# threes.txt
# timber.txt
# time formats.txt
# times.txt
# transgenic.txt
# trees.txt
# twosample.txt
# twoseries.txt
# twoway.txt
# undirected.txt
# varcalc.txt
# Varcell.txt
# w.test.data.txt
# weibull.growth.txt
# wings.txt
# workstoppages.txt
# worldfloras.txt
# worms.missing.txt
# worms.txt
# worms2.txt
# wormsna.txt
# xh.txt
# xv.txt
# xv2.txt
# xvals.txt
# yields.txt
# Yoda.txt
# ys.txt
# ys2.txt
# yvals.txt
# zvals.txt
# 2018_1_summarizeTheWeather\resources\Environmental_Data_Deep_Moor_2012.txt
# 2018_1_summarizeTheWeather\resources\Environmental_Data_Deep_Moor_2013.txt
# 2018_1_summarizeTheWeather\resources\Environmental_Data_Deep_Moor_2014.txt
# 2018_1_summarizeTheWeather\resources\Environmental_Data_Deep_Moor_2015.txt
# PremierLeague\goalkeepers-glossary-1920.txt
# PremierLeague\players-glossary-1920.txt
# PremierLeague\scoresfixtures-glossary-1920.txt
# PremierLeague\standings-glossary-1920.txt
# PremierLeague\teamgoalkeeping-glossary-1920.txt
# PremierLeague\teamstats-glossary-1920.txt
# R programming in Data Science\01_06 base r optimal\stylo_config.txt
# R programming in Data Science\01_06 base r optimal\table_with_frequencies.txt
# R programming in Data Science\01_06 base r optimal\wordlist.txt
# R programming in Data Science\01_06 base r optimal\corpus\A_Midsummer_Nights_Dream.txt
# R programming in Data Science\01_06 base r optimal\corpus\fallushr.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-alls-11.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-as-12.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-comedy-7.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-loves-8.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-merchant-5.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-merry-15.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-midsummer-16.txt
# R programming in Data Science\01_06 base r optimal\corpus\shakespeare-much-3.txt
# R programming in Data Science\02_04 tidyverse optimal\A_Midsummer_Nights_Dream.txt
# R programming in Data Science\02_04 tidyverse optimal\characters.txt
# R programming in Data Science\05_02 command line R\sampleText.txt
